# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib notebook

# %%
file = "./data/SimulatedData.xlsx"
data = pd.read_excel(file, sheet_name=0)
data["NumOfWeek"] = (data["Season"]-1)*12 + data["Week"]

# %%
data["NumOfWeek"].max()
# Out:
# 600

# %%
week5 = data[data["NumOfWeek"] == 5]
week5[week5["SKU"] == "A"].iloc[:, 3:10]
# Out:
#       ValueB1     ValueB2     ValueB3    ValueB4  ValueB5    ValueB6  \
# 4  311.041244  408.638048  435.721151  46.910695      0.0  91.404868
#
#       ValueB7
# 4  816.548924

# %%
da = data[data["SKU"] == "A"].iloc[:, 3:10].reset_index()
del da["index"]
da["weekMean"] = da.mean(1)
da["weekMean"].rolling(12).mean().plot()
# db.plot()
# Out:
# <img src="data:image/png;base64,..." width="985">

# %%
da
# Out:
#      index     ValueB1     ValueB2     ValueB3     ValueB4     ValueB5  \
# 0        0  838.350764  781.069723  563.269441  141.161300    0.000000
# 1        1  789.094764  526.168053  805.645805  408.356216  293.022596
# 2        2    0.000000  919.878520  948.806674  966.230533    0.000000
# 3        3  558.057385  950.968948  619.267334  722.561173  842.795311
# 4        4  311.041244  408.638048  435.721151   46.910695    0.000000
# 5        5  229.104822    0.000000    0.000000  324.275849    0.000000
# 6        6  423.867156  543.179811  478.633997  101.644521  100.704503
# 7        7    0.000000    0.000000   24.803684  215.821378  609.734637
# 8        8  625.052383  613.336215  371.707089  152.594479  220.931497
# 9        9  101.196352  305.515553    0.000000  143.484469  403.763691
# 10      10  469.777771   63.949261  417.515413   81.215435  567.827002
# 11      11  108.093537  377.219980    0.000000  499.478341  100.632586
# ...
